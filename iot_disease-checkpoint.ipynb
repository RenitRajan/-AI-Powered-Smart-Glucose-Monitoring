# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from scipy.stats import boxcox
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('iot.csv')
df
# Out:
#     Age   temp Sex ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0    40  36.58   M           ATA        140          289          0
# 1    49  36.73   F           NAP        160          180          0
# 2    37  36.93   M           ATA        130          283          0
# 3    48  37.15   F           ASY        138          214          0
# 4    54  37.23   M           NAP        150          195          0
# ..  ...    ...  ..           ...        ...          ...        ...
# 95   58  37.73   M           ASY        130          263          0
# 96   43  37.77   M           ATA        142          207          0
# 97   39  38.01   M           NAP        160          147          1
# 98   56  38.04   M           ASY        120           85          0
# 99   41  38.07   M           ATA        125          269          0
#
#    RestingECG  MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      Normal    172              N      0.0       Up             0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
gender_le = LabelEncoder()
gender_le.fit(['M','F'])
gender_le.classes_
df['Sex'] = gender_le.transform(df['Sex'])

# %%
ecg_le = LabelEncoder()
ecg_le.fit(df['ChestPainType'])
df['ChestPainType'] = ecg_le.transform(df['ChestPainType'])
ecg_le.classes_
# Out:
# array(['ASY', 'ATA', 'NAP'], dtype=object)

# %%
ecg_le = LabelEncoder()
ecg_le.fit(df['RestingECG'])
df['RestingECG'] = ecg_le.transform(df['RestingECG'])
ecg_le.classes_
# Out:
# array(['Normal', 'ST'], dtype=object)

# %%
exg_le = LabelEncoder()
exg_le.fit(df['ExerciseAngina'])
df['ExerciseAngina'] = exg_le.transform(df['ExerciseAngina'])
exg_le.classes_
# Out:
# array(['N', 'Y'], dtype=object)

# %%
st_le = LabelEncoder()
st_le.fit(df['ST_Slope'])
df['ST_Slope'] = st_le.transform(df['ST_Slope'])

# %%
df
# Out:
#     Age   temp  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0    40  36.58    1              1        140          289          0
# 1    49  36.73    0              2        160          180          0
# 2    37  36.93    1              1        130          283          0
# 3    48  37.15    0              0        138          214          0
# 4    54  37.23    1              2        150          195          0
# ..  ...    ...  ...            ...        ...          ...        ...
# 95   58  37.73    1              0        130          263          0
# 96   43  37.77    1              1        142          207          0
# 97   39  38.01    1              2        160          147          1
# 98   56  38.04    1              0        120           85          0
# 99   41  38.07    1              1        125          269          0
#
#     RestingECG  MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
X = df.values[:,:-1]
Y = df.values[:,-1:]
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)
clf = LogisticRegression(random_state=0)
clf.fit(X_train, y_train)
print("validation accuracy: ",clf.score(X_test,y_test))
# Out:
# validation accuracy:  0.8787878787878788

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X_train, y_train)
print("validation accuracy: ",clf.score(X_test,y_test))
# Out:
# validation accuracy:  0.8181818181818182

# %%
from sklearn.svm import SVC
clf = SVC()
clf.fit(X_train, y_train)
print("validation accuracy: ",clf.score(X_test,y_test))
# Out:
# validation accuracy:  0.696969696969697
